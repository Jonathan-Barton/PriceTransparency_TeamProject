# %%
import pandas as pd
import csv

# %%
SFLB = pd.read_csv('SF and LB Hospital Combined Dataframe.csv', header =0)
LASSEA = pd.read_csv('main_dataset.csv', header =0)
SLC= pd.read_csv('SLC_Hospitals.csv', header =0)
# Out:
# C:\Users\u0955471\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\u0955471\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\u0955471\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dataframes = [SFLB, LASSEA, SLC]
masterDataset = pd.concat(dataframes)

# %%
masterDataset.head()
# Out:
#   Airport_Code    Hospital_Name                     Procedure_Description  \
# 0           SF  SF - Zuckerberg  Hc Surgery, Trauma Major I, Addl 30 Mins
# 1           SF  SF - Zuckerberg         Hc Post Drain & Percussion 30 Min
# 2           SF  SF - Zuckerberg    Hc Surgery, Minor I, C&g, Addl 30 Mins
# 3           SF  SF - Zuckerberg   Hc Surgery, Minor Ii, C&g, Addl 30 Mins
# 4           SF  SF - Zuckerberg            LAB PATHOLOGY CONSULT-COMPLETE
#
#   Cash_Price Gross_Price  CPT_Code  Number_Beds  For_Profit  \
# 0     3367.7      3367.7  3.60E+11          397           0
# 1     218.45      218.45     94667          397           0
# 2    2214.25     2214.25  3.61E+11          397           0
# 3    2367.25     2367.25  3.61E+11          397           0
# 4       25.5        25.5     80502          397           0
#
#    Yearly_Discharges  Patient_Experience_Rating  Unnamed: 10  Unnamed: 11  \
# 0              15244                          3          NaN          NaN
# 1              15244                          3          NaN          NaN
# 2              15244                          3          NaN          NaN
# 3              15244                          3          NaN          NaN
# 4              15244                          3          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 17
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
masterDataset.head()
# Out:
#   Airport_Code    Hospital_Name                     Procedure_Description  \
# 0           SF  SF - Zuckerberg  Hc Surgery, Trauma Major I, Addl 30 Mins
# 1           SF  SF - Zuckerberg         Hc Post Drain & Percussion 30 Min
# 2           SF  SF - Zuckerberg    Hc Surgery, Minor I, C&g, Addl 30 Mins
# 3           SF  SF - Zuckerberg   Hc Surgery, Minor Ii, C&g, Addl 30 Mins
# 4           SF  SF - Zuckerberg            LAB PATHOLOGY CONSULT-COMPLETE
#
#   Cash_Price Gross_Price  CPT_Code  Number_Beds  For_Profit  \
# 0     3367.7      3367.7  3.60E+11          397           0
# 1     218.45      218.45     94667          397           0
# 2    2214.25     2214.25  3.61E+11          397           0
# 3    2367.25     2367.25  3.61E+11          397           0
# 4       25.5        25.5     80502          397           0
#
#    Yearly_Discharges  Patient_Experience_Rating  Unnamed: 10  Unnamed: 11  \
# 0              15244                          3          NaN          NaN
# 1              15244                          3          NaN          NaN
# 2              15244                          3          NaN          NaN
# 3              15244                          3          NaN          NaN
# 4              15244                          3          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 17
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
masterDataset.to_csv('master_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-6-8edb4d367153> in <module>
# ----> 1 masterDataset.to_csv('master_dataset.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'master_dataset.csv'
