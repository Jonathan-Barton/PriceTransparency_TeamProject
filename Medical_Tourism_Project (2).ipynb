# %%
import pandas as pd

# %%
# Las Vegas - Desert Springs
desert_springs = pd.read_csv("C:/Users/jefft/OneDrive/Documents/GitHub/PriceTransparency_TeamProject/LasVegas_desertsprings_cleaned.csv", encoding= 'UTF-8')

# %%
desert_springs.head(5)
# Out:
#           CDM  Code Type   Code                     Description  \
# 0  34800011.0  CPT/HCPCS  97802           MNT INITIAL EA 15 MIN
# 1  34800029.0  CPT/HCPCS  97803      MNT RE-ASSESSMENT EA 15MIN
# 2  34800037.0  CPT/HCPCS  97804    MNT GROUP EDUCATION EA 30MIN
# 3  34800045.0  CPT/HCPCS  G0270  MNT INDIVIDL 15MIN 2ND REFERAL
# 4  34800060.0  CPT/HCPCS  G0108    DIAB EDUC SMT INDIV EA 30MIN
#
#     Gross Charge     Cash Price
# 0            $147            $59
# 1            $124            $50
# 2             $69            $28
# 3            $124            $50
# 4            $389           $156

# %%
desert_springs.columns
# Out:
# Index(['CDM', 'Code Type', 'Code', 'Description', '  Gross Charge  ',
#        '  Cash Price  '],
#       dtype='object')

# %%
# Add new columns - Las Vegas - Desert Springs
desert_springs["Airport_Code"] = 'LAS'
desert_springs["Hospital_Name"] = 'Desert Springs'
desert_springs["Procedure_Description"] = desert_springs['Description']
desert_springs["Gross_Price"] = desert_springs['  Gross Charge  ']
desert_springs["Cash_Price"] = desert_springs['  Cash Price  ']
desert_springs["CPT_Code"] = desert_springs['Code']
desert_springs["Number_Beds"] = 245
desert_springs["For_Profit"] = 1
desert_springs["Yearly_Discharges"] = 12696
desert_springs["Patient_Experience_Rating"] = 2

# %%
desert_springs_cols = ['Airport_Code','Hospital_Name','Procedure_Description','Cash_Price','Gross_Price','CPT_Code','Number_Beds',
'For_Profit','Yearly_Discharges','Patient_Experience_Rating']
main_desert_springs = desert_springs[desert_springs_cols]
main_desert_springs.head(5)
# Out:
#   Airport_Code   Hospital_Name           Procedure_Description Cash_Price  \
# 0          LAS  Desert Springs           MNT INITIAL EA 15 MIN       $59
# 1          LAS  Desert Springs      MNT RE-ASSESSMENT EA 15MIN       $50
# 2          LAS  Desert Springs    MNT GROUP EDUCATION EA 30MIN       $28
# 3          LAS  Desert Springs  MNT INDIVIDL 15MIN 2ND REFERAL       $50
# 4          LAS  Desert Springs    DIAB EDUC SMT INDIV EA 30MIN      $156
#
#   Gross_Price CPT_Code  Number_Beds  For_Profit  Yearly_Discharges  \
# 0       $147     97802          245           1              12696
# 1       $124     97803          245           1              12696
# 2        $69     97804          245           1              12696
# 3       $124     G0270          245           1              12696
# 4       $389     G0108          245           1              12696
#
#    Patient_Experience_Rating
# 0                          2
# 1                          2
# 2                          2
# 3                          2
# 4                          2

# %%
# Las Vegas - Summerlin Hospital
summerlin = pd.read_csv("C:/Users/jefft/OneDrive/Documents/GitHub/PriceTransparency_TeamProject/LasVegas_summerlin_cleaned.csv", encoding= 'UTF-8')

# %%
summerlin.head(5)
# Out:
#           CDM  Code Type   Code                     Description  \
# 0  34800060.0  CPT/HCPCS  G0108    DIAB EDUC SMT INDIV EA 30MIN
# 1  34800078.0  CPT/HCPCS  G0108   GESTATIONAL DM EDUC SMT 30MIN
# 2  34800086.0  CPT/HCPCS  G0108    INSULIN DM EDUC SMT EA 30MIN
# 3  34800094.0  CPT/HCPCS  G0109  DIABETES ED SMT GROUP EA 30MIN
# 4  34800110.0  CPT/HCPCS  G0109   GESTATIONAL DM ED GROUP 30MIN
#
#     Gross Charge     Cash Price
# 0            $361           $144
# 1            $361           $144
# 2            $361           $144
# 3            $177            $71
# 4            $152            $61

# %%
summerlin.columns
# Out:
# Index(['CDM', 'Code Type', 'Code', 'Description', '  Gross Charge  ',
#        '  Cash Price  '],
#       dtype='object')

# %%
# Add new columns - Las Vegas - Summerlin Hospital
summerlin["Airport_Code"] = 'LAS'
summerlin["Hospital_Name"] = 'Summerlin Hospital'
summerlin["Procedure_Description"] = summerlin['Description']
summerlin["Gross_Price"] = summerlin['  Gross Charge  ']
summerlin["Cash_Price"] = summerlin['  Cash Price  ']
summerlin["CPT_Code"] = summerlin['Code']
summerlin["Number_Beds"] = 421
summerlin["For_Profit"] = 1
summerlin["Yearly_Discharges"] = 23438
summerlin["Patient_Experience_Rating"] = 2

# %%
summerlin_cols = ['Airport_Code','Hospital_Name','Procedure_Description','Cash_Price','Gross_Price','CPT_Code','Number_Beds',
'For_Profit','Yearly_Discharges','Patient_Experience_Rating']
main_summerlin = summerlin[summerlin_cols]
main_summerlin.head(5)
# Out:
#   Airport_Code       Hospital_Name           Procedure_Description Cash_Price  \
# 0          LAS  Summerlin Hospital    DIAB EDUC SMT INDIV EA 30MIN      $144
# 1          LAS  Summerlin Hospital   GESTATIONAL DM EDUC SMT 30MIN      $144
# 2          LAS  Summerlin Hospital    INSULIN DM EDUC SMT EA 30MIN      $144
# 3          LAS  Summerlin Hospital  DIABETES ED SMT GROUP EA 30MIN       $71
# 4          LAS  Summerlin Hospital   GESTATIONAL DM ED GROUP 30MIN       $61
#
#   Gross_Price CPT_Code  Number_Beds  For_Profit  Yearly_Discharges  \
# 0       $361     G0108          421           1              23438
# 1       $361     G0108          421           1              23438
# 2       $361     G0108          421           1              23438
# 3       $177     G0109          421           1              23438
# 4       $152     G0109          421           1              23438
#
#    Patient_Experience_Rating
# 0                          2
# 1                          2
# 2                          2
# 3                          2
# 4                          2

# %%
# Las Vegas - Valley Hospital
valley = pd.read_csv("C:/Users/jefft/OneDrive/Documents/GitHub/PriceTransparency_TeamProject/LasVegas_valley_hospital_cleaned.csv", encoding= 'UTF-8')

# %%
valley.head(5)
# Out:
#           CDM  Code Type   Code                     Description  \
# 0  34800060.0  CPT/HCPCS  G0108    DIAB EDUC SMT INDIV EA 30MIN
# 1  34800078.0  CPT/HCPCS  G0108   GESTATIONAL DM EDUC SMT 30MIN
# 2  34800086.0  CPT/HCPCS  G0108    INSULIN DM EDUC SMT EA 30MIN
# 3  34800094.0  CPT/HCPCS  G0109  DIABETES ED SMT GROUP EA 30MIN
# 4  34800102.0  CPT/HCPCS  G0109    INSULIN DM ED GROUP EA 30MIN
#
#     Gross Charge     Cash Price
# 0            $394           $158
# 1            $394           $158
# 2            $394           $158
# 3            $205            $82
# 4            $178            $71

# %%
valley.columns
# Out:
# Index(['CDM', 'Code Type', 'Code', 'Description', '  Gross Charge  ',
#        '  Cash Price  '],
#       dtype='object')

# %%
# Add new columns - Las Vegas - Valley Hospital
valley["Airport_Code"] = 'LAS'
valley["Hospital_Name"] = 'Valley Hospital'
valley["Procedure_Description"] = valley['Description']
valley["Gross_Price"] = valley['  Gross Charge  ']
valley["Cash_Price"] = valley['  Cash Price  ']
valley["CPT_Code"] = valley['Code']
valley["Number_Beds"] = 297
valley["For_Profit"] = 1
valley["Yearly_Discharges"] = 15266
valley["Patient_Experience_Rating"] = 2

# %%
valley_cols = ['Airport_Code','Hospital_Name','Procedure_Description','Cash_Price','Gross_Price','CPT_Code','Number_Beds',
'For_Profit','Yearly_Discharges','Patient_Experience_Rating']
main_valley = valley[valley_cols]
main_valley.head(5)
# Out:
#   Airport_Code    Hospital_Name           Procedure_Description Cash_Price  \
# 0          LAS  Valley Hospital    DIAB EDUC SMT INDIV EA 30MIN      $158
# 1          LAS  Valley Hospital   GESTATIONAL DM EDUC SMT 30MIN      $158
# 2          LAS  Valley Hospital    INSULIN DM EDUC SMT EA 30MIN      $158
# 3          LAS  Valley Hospital  DIABETES ED SMT GROUP EA 30MIN       $82
# 4          LAS  Valley Hospital    INSULIN DM ED GROUP EA 30MIN       $71
#
#   Gross_Price CPT_Code  Number_Beds  For_Profit  Yearly_Discharges  \
# 0       $394     G0108          297           1              15266
# 1       $394     G0108          297           1              15266
# 2       $394     G0108          297           1              15266
# 3       $205     G0109          297           1              15266
# 4       $178     G0109          297           1              15266
#
#    Patient_Experience_Rating
# 0                          2
# 1                          2
# 2                          2
# 3                          2
# 4                          2

# %%
# Seattle - Virginia Mason
virginia_mason = pd.read_csv("C:/Users/jefft/OneDrive/Documents/GitHub/PriceTransparency_TeamProject/Virginia_mason_Seattle.csv", encoding= 'UTF-8')

# %%
virginia_mason.head(5)
# Out:
#   Chargecode                              Description CPT/HCPCS   Fee
# 0     00000F   INVALID PROCEDURE CODE TES - HPA BOUND       NaN   NaN
# 1      0001A   VACCINE ADMIN, PFIZER 1ST COVID VAC IM     0001A  40.0
# 2      0002A   VACCINE ADMIN, PFIZER 2ND COVID VAC IM     0002A  40.0
# 3      0011A  VACCINE ADMIN, MODERNA 1ST COVID VAC IM     0011A  40.0
# 4      0012A  VACCINE ADMIN, MODERNA 2ND COVID VAC IM     0012A  40.0

# %%
virginia_mason.columns
# Out:
# Index(['Chargecode', 'Description', 'CPT/HCPCS', 'Fee'], dtype='object')

# %%
# Add new columns - Seattle - Virginia Mason Hospital
virginia_mason["Airport_Code"] = 'SEA'
virginia_mason["Hospital_Name"] = 'Virginia Mason'
virginia_mason["Procedure_Description"] = virginia_mason['Description']
virginia_mason["Gross_Price"] = virginia_mason['Fee']
virginia_mason["Cash_Price"] = None
virginia_mason["CPT_Code"] = virginia_mason['CPT/HCPCS']
virginia_mason["Number_Beds"] = 255
virginia_mason["For_Profit"] = 0
virginia_mason["Yearly_Discharges"] = 12093
virginia_mason["Patient_Experience_Rating"] = 4

# %%
virginia_mason_cols = ['Airport_Code','Hospital_Name','Procedure_Description','Cash_Price','Gross_Price','CPT_Code','Number_Beds',
'For_Profit','Yearly_Discharges','Patient_Experience_Rating']
main_virginia_mason = virginia_mason[virginia_mason_cols]
main_virginia_mason.head(5)
# Out:
#   Airport_Code   Hospital_Name                    Procedure_Description  \
# 0          SEA  Virginia Mason   INVALID PROCEDURE CODE TES - HPA BOUND
# 1          SEA  Virginia Mason   VACCINE ADMIN, PFIZER 1ST COVID VAC IM
# 2          SEA  Virginia Mason   VACCINE ADMIN, PFIZER 2ND COVID VAC IM
# 3          SEA  Virginia Mason  VACCINE ADMIN, MODERNA 1ST COVID VAC IM
# 4          SEA  Virginia Mason  VACCINE ADMIN, MODERNA 2ND COVID VAC IM
#
#   Cash_Price  Gross_Price CPT_Code  Number_Beds  For_Profit  \
# 0       None          NaN      NaN          255           0
# 1       None         40.0    0001A          255           0
# 2       None         40.0    0002A          255           0
# 3       None         40.0    0011A          255           0
# 4       None         40.0    0012A          255           0
#
#    Yearly_Discharges  Patient_Experience_Rating
# 0              12093                          4
# 1              12093                          4
# 2              12093                          4
# 3              12093                          4
# 4              12093                          4

# %%
# Seattle - Kaiser Permanente
kaiser = pd.read_csv("C:/Users/jefft/OneDrive/Documents/GitHub/PriceTransparency_TeamProject/KaiserPermannente_Seattle.csv", encoding= 'unicode_escape')

# %%
kaiser.head(5)
# Out:
#   Charge Number                             Procedure Name  \
# 0      17000001                    HB NURSERY ROOM & BOARD
# 1      17200001                    HB PREEMIE ROOM & BOARD
# 2      11000001        HB PRIVATE ROOM AND BOARD (ONE BED)
# 3      12000001  HB SEMI-PRIVATE ROOM AND BOARD (TWO BEDS)
# 4      12200001          HB SEMI-PRIVATE ROOM AND BOARD OB
#
#   Procedure Code (CPT/HCPCS) Default Modifier Gross Charge  \
# 0                        NaN              NaN   $1,298.00
# 1                        NaN              NaN   $2,475.00
# 2                        NaN              NaN   $2,035.00
# 3                        NaN              NaN   $2,035.00
# 4                        NaN              NaN   $1,749.00
#
#   Discounted Cash Charge  Hospital Inpatient / Outpatient / Both
# 0                $752.84                               Inpatient
# 1              $1,435.50                               Inpatient
# 2              $1,180.30                               Inpatient
# 3              $1,180.30                               Inpatient
# 4              $1,014.42                               Inpatient

# %%
kaiser.columns
# Out:
# Index(['Charge Number', 'Procedure Name', 'Procedure Code (CPT/HCPCS)',
#        'Default Modifier', 'Gross Charge', 'Discounted Cash Charge ',
#        'Hospital Inpatient / Outpatient / Both', 'Airport_Code',
#        'Hospital_Name', 'Procedure_Description', 'Gross_Price', 'Cash_Price',
#        'CPT_Code', 'Number_Beds', 'For_Profit', 'Yearly_Discharges',
#        'Patient_Experience_Rating'],
#       dtype='object')

# %%
# Add new columns - Seattle - Kaiser Permanente Hospital
kaiser["Airport_Code"] = 'SEA'
kaiser["Hospital_Name"] = 'Kaiser Permannente'
kaiser["Procedure_Description"] = kaiser['Procedure Name']
kaiser["Gross_Price"] = kaiser['Gross Charge']
kaiser["Cash_Price"] = kaiser['Discounted Cash Charge ']
kaiser["CPT_Code"] = kaiser['Procedure Code (CPT/HCPCS)']
kaiser["Number_Beds"] = 306
kaiser["For_Profit"] = 0
kaiser["Yearly_Discharges"] = 16358  #Took Swedish First Hill and divided by 2 based on number of beds.
kaiser["Patient_Experience_Rating"] = 4

# %%
kaiser_cols = ['Airport_Code','Hospital_Name','Procedure_Description','Cash_Price','Gross_Price','CPT_Code','Number_Beds',
'For_Profit','Yearly_Discharges','Patient_Experience_Rating']
main_kaiser = kaiser[kaiser_cols]
main_kaiser.head(5)
# Out:
#   Airport_Code       Hospital_Name                      Procedure_Description  \
# 0          SEA  Kaiser Permannente                    HB NURSERY ROOM & BOARD
# 1          SEA  Kaiser Permannente                    HB PREEMIE ROOM & BOARD
# 2          SEA  Kaiser Permannente        HB PRIVATE ROOM AND BOARD (ONE BED)
# 3          SEA  Kaiser Permannente  HB SEMI-PRIVATE ROOM AND BOARD (TWO BEDS)
# 4          SEA  Kaiser Permannente          HB SEMI-PRIVATE ROOM AND BOARD OB
#
#     Cash_Price  Gross_Price CPT_Code  Number_Beds  For_Profit  \
# 0     $752.84    $1,298.00       NaN          306           0
# 1   $1,435.50    $2,475.00       NaN          306           0
# 2   $1,180.30    $2,035.00       NaN          306           0
# 3   $1,180.30    $2,035.00       NaN          306           0
# 4   $1,014.42    $1,749.00       NaN          306           0
#
#    Yearly_Discharges  Patient_Experience_Rating
# 0              16358                          4
# 1              16358                          4
# 2              16358                          4
# 3              16358                          4
# 4              16358                          4

# %%
# Seattle - Swedish Cherry Hill
cherry_hill = pd.read_csv("C:/Users/jefft/OneDrive/Documents/GitHub/PriceTransparency_TeamProject/SwedishCherryHill_Seattle.csv", encoding= 'UTF-8')

# %%
cherry_hill.head(5)
# Out:
#    Itemcode                               Description  CDM Revenue Code  \
# 0  45010213   HC ED EMERGENCY DEPT VISIT LEVEL IV CDM               450
# 1  45010094        HC ED CRITICAL CARE FIRST HOUR CDM               450
# 2  45010124               HC ED MHU CLASS I BRIEF CDM               450
# 3  45010127           HC ED MHU CLASS IV EXTENDED CDM               450
# 4  45010210  HC ED EMERGENCY DEPT VISIT LEVEL III CDM               450
#
#   CDM Hcpcs CDM Modifier Gross Charge Cash Price SHS OUTPATIENT [108130006]  \
# 0     99284          NaN    $1,981.00  $1,386.70                        NaN
# 1     99291          NaN    $4,112.00  $2,878.40                        NaN
# 2     99281          NaN      $365.00    $255.50                        NaN
# 3     99284          NaN    $1,981.00  $1,386.70                        NaN
# 4     99283          NaN    $1,196.00    $837.20                        NaN
#
#   Note
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
cherry_hill.columns
# Out:
# Index(['Itemcode', 'Description', 'CDM Revenue Code', 'CDM Hcpcs',
#        'CDM Modifier', 'Gross Charge', 'Cash Price',
#        'SHS OUTPATIENT [108130006]', 'Note'],
#       dtype='object')

# %%
# Add new columns - Seattle - Swedish Cherry Hill
cherry_hill["Airport_Code"] = 'SEA'
cherry_hill["Hospital_Name"] = 'Swedish Cherry Hill'
cherry_hill["Procedure_Description"] = cherry_hill['Description']
cherry_hill["Gross_Price"] = cherry_hill['Gross Charge']
cherry_hill["Cash_Price"] = cherry_hill['Cash Price']
cherry_hill["CPT_Code"] = cherry_hill['CDM Hcpcs']
cherry_hill["Number_Beds"] = 210
cherry_hill["For_Profit"] = 1
cherry_hill["Yearly_Discharges"] = 9012
cherry_hill["Patient_Experience_Rating"] = 3

# %%
cherry_hill_cols = ['Airport_Code','Hospital_Name','Procedure_Description','Cash_Price','Gross_Price','CPT_Code','Number_Beds',
'For_Profit','Yearly_Discharges','Patient_Experience_Rating']
main_cherry_hill = cherry_hill[cherry_hill_cols]
main_cherry_hill.head(5)
# Out:
#   Airport_Code        Hospital_Name                     Procedure_Description  \
# 0          SEA  Swedish Cherry Hill   HC ED EMERGENCY DEPT VISIT LEVEL IV CDM
# 1          SEA  Swedish Cherry Hill        HC ED CRITICAL CARE FIRST HOUR CDM
# 2          SEA  Swedish Cherry Hill               HC ED MHU CLASS I BRIEF CDM
# 3          SEA  Swedish Cherry Hill           HC ED MHU CLASS IV EXTENDED CDM
# 4          SEA  Swedish Cherry Hill  HC ED EMERGENCY DEPT VISIT LEVEL III CDM
#
#   Cash_Price Gross_Price CPT_Code  Number_Beds  For_Profit  Yearly_Discharges  \
# 0  $1,386.70   $1,981.00    99284          210           1               9012
# 1  $2,878.40   $4,112.00    99291          210           1               9012
# 2    $255.50     $365.00    99281          210           1               9012
# 3  $1,386.70   $1,981.00    99284          210           1               9012
# 4    $837.20   $1,196.00    99283          210           1               9012
#
#    Patient_Experience_Rating
# 0                          3
# 1                          3
# 2                          3
# 3                          3
# 4                          3

# %%
# Seattle - Swedish Ballard
first_hill = pd.read_csv("C:/Users/jefft/OneDrive/Documents/GitHub/PriceTransparency_TeamProject/SwedishFirstHill_Seattle.csv", encoding= 'UTF-8')

# %%
first_hill.head(5)
# Out:
#    Itemcode                               Description  CDM Revenue Code  \
# 0  45010213   HC ED EMERGENCY DEPT VISIT LEVEL IV CDM               450
# 1  45010094        HC ED CRITICAL CARE FIRST HOUR CDM               450
# 2  45010124               HC ED MHU CLASS I BRIEF CDM               450
# 3  45010127           HC ED MHU CLASS IV EXTENDED CDM               450
# 4  45010210  HC ED EMERGENCY DEPT VISIT LEVEL III CDM               450
#
#   CDM Hcpcs CDM Modifier Gross Price Cash Price SHS OUTPATIENT [108130006]  \
# 0     99284          NaN   $1,981.00  $1,386.70                        NaN
# 1     99291          NaN   $4,112.00  $2,878.40                        NaN
# 2     99281          NaN     $365.00    $255.50                        NaN
# 3     99284          NaN   $1,981.00  $1,386.70                        NaN
# 4     99283          NaN   $1,196.00    $837.20                        NaN
#
#   Note
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
first_hill.columns
# Out:
# Index(['Itemcode', 'Description', 'CDM Revenue Code', 'CDM Hcpcs',
#        'CDM Modifier', 'Gross Price', 'Cash Price',
#        'SHS OUTPATIENT [108130006]', 'Note'],
#       dtype='object')

# %%
# Add new columns - Seattle - Swedish First Hill
first_hill["Airport_Code"] = 'SEA'
first_hill["Hospital_Name"] = 'Swedish First Hill'
first_hill["Procedure_Description"] = first_hill['Description']
first_hill["Gross_Price"] = first_hill['Gross Price']
first_hill["Cash_Price"] = first_hill['Cash Price']
first_hill["CPT_Code"] = first_hill['CDM Hcpcs']
first_hill["Number_Beds"] = 661
first_hill["For_Profit"] = 0
first_hill["Yearly_Discharges"] = 32717
first_hill["Patient_Experience_Rating"] = 3

# %%
first_hill_cols = ['Airport_Code','Hospital_Name','Procedure_Description','Cash_Price','Gross_Price','CPT_Code','Number_Beds',
'For_Profit','Yearly_Discharges','Patient_Experience_Rating']
main_first_hill = first_hill[first_hill_cols]
main_first_hill.head(5)
# Out:
#   Airport_Code       Hospital_Name                     Procedure_Description  \
# 0          SEA  Swedish First Hill   HC ED EMERGENCY DEPT VISIT LEVEL IV CDM
# 1          SEA  Swedish First Hill        HC ED CRITICAL CARE FIRST HOUR CDM
# 2          SEA  Swedish First Hill               HC ED MHU CLASS I BRIEF CDM
# 3          SEA  Swedish First Hill           HC ED MHU CLASS IV EXTENDED CDM
# 4          SEA  Swedish First Hill  HC ED EMERGENCY DEPT VISIT LEVEL III CDM
#
#   Cash_Price Gross_Price CPT_Code  Number_Beds  For_Profit  Yearly_Discharges  \
# 0  $1,386.70   $1,981.00    99284          661           0              32717
# 1  $2,878.40   $4,112.00    99291          661           0              32717
# 2    $255.50     $365.00    99281          661           0              32717
# 3  $1,386.70   $1,981.00    99284          661           0              32717
# 4    $837.20   $1,196.00    99283          661           0              32717
#
#    Patient_Experience_Rating
# 0                          3
# 1                          3
# 2                          3
# 3                          3
# 4                          3

# %%
#Main Dataset
hospitals = [main_first_hill,main_cherry_hill]
main_df = pd.DataFrame()

for hospital in hospitals:
    hosp = hospital
    main_df.append(hosp)

# %%
print(main_first_hill.shape)
print(main_cherry_hill.shape)
print(main_df.shape)
# Out:
# (4353, 10)
# (4353, 10)
# (0, 0)

# %%
#Flight Information
flight = pd.read_csv("C:/Users/jefft/OneDrive/Documents/GitHub/PriceTransparency_TeamProject/Flights.csv")

# %%
flight.head(5)
# Out:
#       origin_city origin_airport_code  month_number month_name dest_city  \
# 0  Salt Lake City                 SLC             1    January   Seattle
# 1  Salt Lake City                 SLC             2   February   Seattle
# 2  Salt Lake City                 SLC             3      March   Seattle
# 3  Salt Lake City                 SLC             4      April   Seattle
# 4  Salt Lake City                 SLC             5        May   Seattle
#
#   dest_airport_code  avg_price
# 0               SEA        147
# 1               SEA        147
# 2               SEA        209
# 3               SEA        197
# 4               SEA        217

# %%
# Concatenate all the datasets together.
main_df = pd.concat([main_desert_springs,main_summerlin,main_valley,main_virginia_mason,main_kaiser,main_cherry_hill,main_first_hill])

# %%
main_df.shape
# Out:
# (337252, 10)

# %%
main_df.to_csv('main_dataset.csv')
