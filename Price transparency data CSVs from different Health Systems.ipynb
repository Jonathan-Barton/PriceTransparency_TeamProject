# %%
import pandas as pd

# %%
alta_view = pd.read_csv("IHC_Alta_View_Hospital.csv", low_memory=False)
alta_view.head()
# Out:
#    CDM  Bill Item Service Code  \
# 0  NaN        NaN          001
# 1  NaN        NaN          001
# 2  NaN        NaN          001
# 3  NaN        NaN          001
# 4  NaN        NaN          001
#
#                                  Service Description  \
# 0  Heart transplant or implant of heart assist sy...
# 1  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...
# 2  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...
# 3  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...
# 4  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...
#
#                             Payer  \
# 0  Health Plan of Nevada Medicaid
# 1               United Healthcare
# 2                         TriWest
# 3                         TriCare
# 4                    SelectHealth
#
#                                             Contract Inpatient Cash Price  \
# 0               Health Plan of Nevada Medicaid (HPN)                $0.00
# 1  United Healthcare Medicare Advantage Complete ...                $0.00
# 2                            TriWest Veterans Choice                $0.00
# 3                    Tricare (HNFS) Military Program                $0.00
# 4   SelectHealth Value Network Individual Plan (ACA)                $0.00
#
#   Inpatient Min Price Inpatient Max Price Inpatient Negotiated Price  \
# 0         $167,176.24         $235,365.68                $167,176.24
# 1         $167,176.24         $235,365.68                $182,641.56
# 2         $167,176.24         $235,365.68                $182,641.56
# 3         $167,176.24         $235,365.68                $235,365.68
# 4         $167,176.24         $235,365.68                $191,773.64
#
#   Outpatient Cash Price Outpatient Min Price Outpatient Max Price  \
# 0                 $0.00                $0.00                $0.00
# 1                 $0.00                $0.00                $0.00
# 2                 $0.00                $0.00                $0.00
# 3                 $0.00                $0.00                $0.00
# 4                 $0.00                $0.00                $0.00
#
#   Outpatient Negotiated Price Charge Price
# 0                       $0.00        $0.00
# 1                       $0.00        $0.00
# 2                       $0.00        $0.00
# 3                       $0.00        $0.00
# 4                       $0.00        $0.00

# %%
lone_peak = pd.read_csv("MountainStar_lone-peak-hospital_standardcharges.csv")

# %%
lone_peak.head()
# Out:
#                                                                   Last updated 1/4/2021 9:41:27 AM
# Procedure ID HCPCS/CPT Code Description              Gross Charge          Undiscounted Cash Price
# 1            093924         DOP LE ART W/EXER BIL    614.76                                 614.76
# 2            07366050       XR TOE(S) 2 + V BI       349.39                                 349.39
# 3            073660RT       XR TOE(S) 2 + V RT       174.68                                 174.68
# 4            073660LT       XR TOE(S) 2 + V LT       174.68                                 174.68

# %%
UofU_health = pd.read_csv("UofU_Health.csv", encoding= 'unicode_escape')
UofU_health.head()
# Out:
#                          PROC NAME CPT CODE  MAIN\nPRICE
# 0            ANCHOR CPS SHORT 14MM      NaN    $2,926.10
# 1                ANCHOR TENDON (8)      NaN      $832.50
# 2   AUG FEM CONE TRIATH TRI 1\T R      NaN   $12,916.00
# 3     AUG FEM VG 360 UNV PST 80X10      NaN    $2,600.70
# 4     AUGMENT TIBIAL BMT 360 71X10      NaN    $2,418.10
