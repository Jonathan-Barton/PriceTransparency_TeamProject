# %%
import pandas as pd

# %% [markdown]
# # Long Beach Hospitals

# %% [markdown]
# ### Long Beach - Harbor-UCLA

# %%
LBHarbor = pd.read_csv('LB- Harbor-UCLA CSV.csv', header=1)
LBHarbor.head()
# Out:
#           PROCEDURE DESCRIPTION     PRICE    REVENUE CODE   CPT CODE   \
# 0   CORONARY CARE UNIT - GENERAL   $9,500            210.0
# 1            INTENSIVE CARE UNIT   $9,500            200.0
# 2  LEAVE OF ABSENCE -  NO CHARGE     $-              180.0
# 3    LEAVE OF ABSENCE - W/CHARGE   $3,500            180.0
# 4     MULTIBED STANDARD ( 3 - 4)   $3,000            130.0
#
#    ALTERNATE CPT HCPC   CPT HCPC MODIFIER   Unnamed: 6  Unnamed: 7
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN

# %% [markdown]
# ### Long Beach - Olive View - UCLA

# %% [markdown]
# LBOlive = pd.read_csv('LB- Olive View-UCLA CSV.csv')
# LBOlive.head()

# %% [markdown]
# ### Long Beach - USC+LAC

# %%
LBUsc = pd.read_csv('LB- USC+ LAC MC.csv')
LBUsc.head()
# Out:
#           PROCEDURE DESCRIPTION     PRICE    REVENUE CODE   CPT CODE   \
# 0   CORONARY CARE UNIT - GENERAL   $9,500            210.0
# 1            INTENSIVE CARE UNIT   $9,500            200.0
# 2  LEAVE OF ABSENCE -  NO CHARGE     $-              180.0
# 3    LEAVE OF ABSENCE - W/CHARGE   $3,500            180.0
# 4     MULTIBED STANDARD ( 3 - 4)   $3,000            130.0
#
#    ALTERNATE CPT HCPC   CPT HCPC MODIFIER
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # San Francisco Hospitals #

# %% [markdown]
# ### SF- Van Ness

# %%
SFVanness = pd.read_csv('SF- Van Ness MC CSV.csv')
SFVanness.head()
# Out:
#              ID SERVICE_SETTING                              DESCRIPTION  CPT  \
# 0  APRDRG-004-1       INPATIENT  All Inpatient Services for APRDRG-004-1  NaN
# 1  APRDRG-004-2       INPATIENT  All Inpatient Services for APRDRG-004-2  NaN
# 2  APRDRG-004-3       INPATIENT  All Inpatient Services for APRDRG-004-3  NaN
# 3  APRDRG-004-4       INPATIENT  All Inpatient Services for APRDRG-004-4  NaN
# 4  APRDRG-005-1       INPATIENT  All Inpatient Services for APRDRG-005-1  NaN
#
#    NDC  REVENUE_CODE Gross Charge Discounted Cash Price  \
# 0  NaN           NaN          NaN                   NaN
# 1  NaN           NaN          NaN                   NaN
# 2  NaN           NaN          NaN                   NaN
# 3  NaN           NaN          NaN                   NaN
# 4  NaN           NaN          NaN                   NaN
#
#   Aetna Commercial Out of Network Aetna HMO/PPO  ...  \
# 0                             NaN           NaN  ...
# 1                             NaN           NaN  ...
# 2                             NaN           NaN  ...
# 3                             NaN           NaN  ...
# 4                             NaN           NaN  ...
#
#   Sutter | Aetna Fully Insured Sutter | Aetna Self Insured  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#   Sutter Health Plus HMO United Commercial Out of Network United HMO / POS  \
# 0                    NaN                              NaN              NaN
# 1                    NaN                              NaN              NaN
# 2                    NaN                              NaN              NaN
# 3                    NaN                              NaN              NaN
# 4                    NaN                              NaN              NaN
#
#   United Medicare Adv_ HMO United PPO United Signature Value Alliance  \
# 0                      NaN        NaN                             NaN
# 1                      NaN        NaN                             NaN
# 2                      NaN        NaN                             NaN
# 3                      NaN        NaN                             NaN
# 4                      NaN        NaN                             NaN
#
#   Minimum Negotiated Price Maximum Negotiated Price
# 0               $49,900.00               $84,830.00
# 1               $64,226.00              $109,184.00
# 2               $90,505.00              $153,859.00
# 3              $147,647.00              $251,000.00
# 4               $45,662.00               $77,626.00
#
# [5 rows x 46 columns]

# %% [markdown]
# ### SF San Mateo

# %%
SFSanmateo= pd.read_csv('SF-San Mateo MC CSV.csv')
SFSanmateo.head()
# Out:
#                    PROCEDURE CPT/HCPCS  CURRENT PRICE     Service type  \
# 0      FLOOR 1 NON-ACUTE AWL         -        $985.00   Long Term Care
# 1       FLOOR 1 PRIVATE ROOM         -      $1,182.00   Long Term Care
# 2       FLOOR 1 SEMI PRIVATE         -        $985.00   Long Term Care
# 3       MED-SURG BED PRIVATE         -      $5,640.00   Long Term Care
# 4  MED-SURG BED SEMI-PRIVATE         -      $4,700.00   Long Term Care
#
#    Cash if paid within 30 days of first statement 50% discount   \
# 0                                           $492.50
# 1                                           $591.00
# 2                                           $492.50
# 3                                         $2,820.00
# 4                                         $2,350.00
#
#    Discounted Health Care 35% of total charges   HPSM Negotiated Rate   \
# 0                                      $344.75                $484.30
# 1                                      $413.70                $484.30
# 2                                      $344.75                $484.30
# 3                                    $1,974.00                $484.30
# 4                                    $1,645.00                $484.30
#
#    Pharmacy NDC
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# ### SF - Zuckerberg

# %%
SFZuckerberg = pd.read_csv('SF-Zuckerberg Gen CSV.csv', header=2)
SFZuckerberg.head()
# Out:
# C:\Users\u0955471\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#      Procedure Code Type                 Code  NDC  \
# 0  3.60442E+11       EAP  Custom 360442132010  NaN
# 1  4.10472E+11       EAP           CPT® 94667  NaN
# 2  3.61443E+11       EAP  Custom 361442632011  NaN
# 3  3.61443E+11       EAP  Custom 361442632012  NaN
# 4        80502       EAP           CPT® 80502  NaN
#
#                                             Rev Code  \
# 0  0360 - OPERATING ROOM SERVICES - GENERAL CLASS...
# 1  0410 - RESPIRATORY SERVICES - GENERAL CLASSIFI...
# 2     0361 - OPERATING ROOM SERVICES - MINOR SURGERY
# 3     0361 - OPERATING ROOM SERVICES - MINOR SURGERY
# 4         0300 - LABORATORY - GENERAL CLASSIFICATION
#
#                       Procedure Description  Quantity  \
# 0  Hc Surgery, Trauma Major I, Addl 30 Mins         1
# 1         Hc Post Drain & Percussion 30 Min         1
# 2    Hc Surgery, Minor I, C&g, Addl 30 Mins         1
# 3   Hc Surgery, Minor Ii, C&g, Addl 30 Mins         1
# 4            LAB PATHOLOGY CONSULT-COMPLETE         1
#
#    Anthem Blue Cross Commercial HMO - IP Price  \
# 0                                       3962.0
# 1                                        257.0
# 2                                       2605.0
# 3                                       2785.0
# 4                                         30.0
#
#    Anthem Blue Cross Commercial HMO - IP Expected Reimbursement  \
# 0                                            3367.70
# 1                                             218.45
# 2                                            2214.25
# 3                                            2367.25
# 4                                              25.50
#
#    Anthem Blue Cross Commercial HMO - ED Price  ...  Unnamed: 246  \
# 0                                       3962.0  ...           NaN
# 1                                        257.0  ...           NaN
# 2                                       2605.0  ...           NaN
# 3                                       2785.0  ...           NaN
# 4                                         30.0  ...           NaN
#
#    Unnamed: 247  Unnamed: 248  Unnamed: 249  Unnamed: 250  Unnamed: 251  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 252  Unnamed: 253  Unnamed: 254  Unnamed: 255
# 0           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN
#
# [5 rows x 256 columns]
